# %%
import pandas as pd
import numpy as np
import math
import pickle

import sys
import traceback
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Process vs Product

# %% [markdown]
# ## with and without CFS

# %%
df_PoPr = pd.read_pickle('results/Performance/process+product_1000.pkl')
df_pr = pd.read_pickle('results/Performance/product_1000.pkl')
df_po = pd.read_pickle('results/Performance/process_1000.pkl')
df_PoPr_CFS = pd.read_pickle('results/Performance/process+product_CFS.pkl')
df_pr_CFS = pd.read_pickle('results/Performance/product_1000_CFS.pkl')
df_po_CFS = pd.read_pickle('results/Performance/process_1000_CFS.pkl')
for key in df_w.keys():
    with open('results/Stats/process_vs_product/' + key + '.txt', 'w') as f:
        f.write("%s \n" % "Process+Product")  # Process + Product without CFS
        for item in df_PoPr[key]:
            try:
                if math.isnan(df_PoPr[key][item]):
                    continue
                f.write("%s " % df_PoPr[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Product") # Product without CFS
        for item in df_pr[key]:
            try:
                if math.isnan(df_pr[key][item]):
                    continue
                f.write("%s " % df_pr[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process") # Process without CFS
        for item in df_po[key]:
            try:
                if math.isnan(df_po[key][item]):
                    continue
                f.write("%s " % df_po[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process+Product_CFS") # Process + Product with CFS
        for item in df_PoPr_CFS[key]:
            try:
                if math.isnan(df_PoPr_CFS[key][item]):
                    continue
                f.write("%s " % df_PoPr_CFS[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Product_CFS")  # Product with CFS
        for item in df_pr_CFS[key]:
            try:
                if math.isnan(df_pr_CFS[key][item]):
                    continue
                f.write("%s " % df_pr_CFS[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process_CFS") # Process with CFS
        for item in df_po_CFS[key]:
            try:
                if math.isnan(df_po_CFS[key][item]):
                    continue
                f.write("%s " % df_po_CFS[key][item])
            except:
                print('error')
                continue

# %%
## Different Models

# %%
df_PoPr = pd.read_pickle('results/Performance/process+product_1000.pkl')
df_pr = pd.read_pickle('results/Performance/product_1000.pkl')
df_po = pd.read_pickle('results/Performance/process_1000.pkl')
df_PoPr_logistic = pd.read_pickle('results/Performance/process+product_logistic.pkl')
df_pr_logistic = pd.read_pickle('results/Performance/product_1000_logistic.pkl')
df_po_logistic = pd.read_pickle('results/Performance/process_1000_logistic.pkl')
df_PoPr_svm = pd.read_pickle('results/Performance/process+product_svm.pkl')
df_pr_svm = pd.read_pickle('results/Performance/product_1000_svm.pkl')
df_po_svm = pd.read_pickle('results/Performance/process_1000_svm.pkl')
df_PoPr_nb = pd.read_pickle('results/Performance/process+product_nb.pkl')
df_pr_nb = pd.read_pickle('results/Performance/product_1000_nb.pkl')
df_po_nb = pd.read_pickle('results/Performance/process_1000_nb.pkl')
for key in df_w.keys():
    with open('results/Stats/process_vs_product/' + key + '.txt', 'w') as f:
        f.write("%s \n" % "Process+Product")  # Process + Product without CFS
        for item in df_PoPr[key]:
            try:
                if math.isnan(df_PoPr[key][item]):
                    continue
                f.write("%s " % df_PoPr[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Product") # Product without CFS
        for item in df_pr[key]:
            try:
                if math.isnan(df_pr[key][item]):
                    continue
                f.write("%s " % df_pr[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process") # Process without CFS
        for item in df_po[key]:
            try:
                if math.isnan(df_po[key][item]):
                    continue
                f.write("%s " % df_po[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process+Product_logistic") # Process + Product with CFS
        for item in df_PoPr_logistic[key]:
            try:
                if math.isnan(df_PoPr_logistic[key][item]):
                    continue
                f.write("%s " % df_PoPr_logistic[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Product_logistic")  # Product with CFS
        for item in df_pr_logistic[key]:
            try:
                if math.isnan(df_pr_logistic[key][item]):
                    continue
                f.write("%s " % df_pr_logistic[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process_logistic") # Process with CFS
        for item in df_po_logistic[key]:
            try:
                if math.isnan(df_po_logistic[key][item]):
                    continue
                f.write("%s " % df_po_logistic[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process+Product_svm") # Process + Product with CFS
        for item in df_PoPr_svm[key]:
            try:
                if math.isnan(df_PoPr_svm[key][item]):
                    continue
                f.write("%s " % df_PoPr_svm[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Product_svm")  # Product with CFS
        for item in df_pr_svm[key]:
            try:
                if math.isnan(df_pr_svm[key][item]):
                    continue
                f.write("%s " % df_pr_svm[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process_svm") # Process with CFS
        for item in df_po_svm[key]:
            try:
                if math.isnan(df_po_svm[key][item]):
                    continue
                f.write("%s " % df_po_svm[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process+Product_nb") # Process + Product with CFS
        for item in df_PoPr_nb[key]:
            try:
                if math.isnan(df_PoPr_nb[key][item]):
                    continue
                f.write("%s " % df_PoPr_nb[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Product_nb")  # Product with CFS
        for item in df_pr_nb[key]:
            try:
                if math.isnan(df_pr_nb[key][item]):
                    continue
                f.write("%s " % df_pr_nb[key][item])
            except:
                print('error')
                continue
                
        f.write("%s \n" % "Process_nb") # Process with CFS
        for item in df_po_nb[key]:
            try:
                if math.isnan(df_po_nb[key][item]):
                    continue
                f.write("%s " % df_po_nb[key][item])
            except:
                print('error')
                continue

# %%
df_w = pd.read_pickle('results/Performance/process+product_1000.pkl')
df_1 = pd.read_pickle('results/Performance/strategy_1_1000.pkl')
df_2 = pd.read_pickle('results/Performance/strategy_2_1000.pkl')
df_3 = pd.read_pickle('results/Performance/strategy_3_1000.pkl')
df_4 = pd.read_pickle('results/Performance/strategy_4_1000.pkl')
for key in df_w.keys():
    with open('results/Stats/commit_size/' + key + '.txt', 'w') as f:
        f.write("%s \n" % "All_Commits")
        for item in df_w[key]:
            try:
#                 print(df_w[key][item],type(df_w[key][item]))
                if math.isnan(df_w[key][item]):# == np.nan:
#                     print(df_w[key][item])
                    continue
                f.write("%s " % df_w[key][item])
            except:
                print('error')
                continue
        f.write("%s \n" % "Strategy_1")
        for item in df_1[key]:
            try:
                if math.isnan(df_1[key][item]):
#                     print(df_wo[key][item])
                    continue
                f.write("%s " % df_1[key][item])
            except:
                print('error')
                continue
        f.write("%s \n" % "Strategy_2")
        for item in df_2[key]:
            try:
                if math.isnan(df_2[key][item]):
#                     print(df_wo[key][item])
                    continue
                f.write("%s " % df_2[key][item])
            except:
                print('error')
                continue
        f.write("%s \n" % "Strategy_3")
        for item in df_3[key]:
            try:
                if math.isnan(df_3[key][item]):
#                     print(df_wo[key][item])
                    continue
                f.write("%s " % df_3[key][item])
            except:
                print('error')
                continue
        f.write("%s \n" % "Strategy_4")
        for item in df_4[key]:
            try:
                if math.isnan(df_4[key][item]):
#                     print(df_wo[key][item])
                    continue
                f.write("%s " % df_4[key][item])
            except:
                print('error')
                continue

# %%
import pandas as pd
import numpy as np
import math
import pickle

from scipy import stats
import scipy.io
from scipy.spatial.distance import pdist
from scipy.linalg import cholesky
from scipy.io import loadmat

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report,roc_auc_score,recall_score,precision_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from pyearth import Earth
from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer
from sklearn.model_selection import StratifiedKFold

from src import SMOTE
from src import CFS
from src import metrices_V2 as metrices

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback
from pathlib import Path

# import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/suvodeepmajumder/Conda/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
def apply_smote(df):
    df.reset_index(drop=True,inplace=True)
    cols = df.columns
    smt = SMOTE.smote(df)
    df = smt.run()
    df.columns = cols
    return df

def apply_cfs(df):
        y = df.Bugs.values
        X = df.drop(labels = ['Bugs'],axis = 1)
        X = X.values
        selected_cols = CFS.cfs(X,y)
        cols = df.columns[[selected_cols]].tolist()
        cols.append('Bugs')
        return df[cols],cols

# %%
def load_both_data(project,metric):
    understand_path = 'data/understand_files_all/' + project + '_understand.csv'
    understand_df = pd.read_csv(understand_path)
    understand_df = understand_df.dropna(axis = 1,how='all')
    cols_list = understand_df.columns.values.tolist()
    for item in ['Kind', 'Name','commit_hash', 'Bugs']:
        if item in cols_list:
            cols_list.remove(item)
            cols_list.insert(0,item)
    understand_df = understand_df[cols_list]
    cols = understand_df.columns.tolist()
    understand_df = understand_df.drop_duplicates(cols[4:len(cols)])
    understand_df['Name'] = understand_df.Name.str.rsplit('.',1).str[1]
    
    commit_guru_file_level_path = 'data/commit_guru_file/' + project + '.csv'
    commit_guru_file_level_df = pd.read_csv(commit_guru_file_level_path)
    commit_guru_file_level_df['commit_hash'] = commit_guru_file_level_df.commit_hash.str.strip('"')
    commit_guru_file_level_df = commit_guru_file_level_df[commit_guru_file_level_df['file_name'].str.contains('.java')]
    commit_guru_file_level_df['Name'] = commit_guru_file_level_df.file_name.str.rsplit('/',1).str[1].str.split('.').str[0].str.replace('/','.')
    commit_guru_file_level_df = commit_guru_file_level_df.drop('file_name',axis = 1)
    
    
    df = understand_df.merge(commit_guru_file_level_df,how='left',on=['commit_hash','Name'])
    
    
    cols = df.columns.tolist()
    cols.remove('Bugs')
    cols.append('Bugs')
    df = df[cols]
    
    for item in ['Kind', 'Name','commit_hash']:
        if item in cols:
            df = df.drop(labels = [item],axis=1)
#     df.dropna(inplace=True)
    df = df.drop_duplicates()
    df.reset_index(drop=True, inplace=True)
    
    y = df.Bugs
    X = df.drop('Bugs',axis = 1)
    cols = X.columns
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)
    X = pd.DataFrame(X,columns = cols)
    imp_mean = IterativeImputer(random_state=0)
    X = imp_mean.fit_transform(X)
    X = pd.DataFrame(X,columns = cols)
    
    if metric == 'process':
        X = X[['file_la', 'file_ld', 'file_lt', 'file_age', 'file_ddev',
       'file_nuc', 'own', 'minor', 'file_ndev', 'file_ncomm', 'file_adev',
       'file_nadev', 'file_avg_nddev', 'file_avg_nadev', 'file_avg_ncomm',
       'file_ns', 'file_exp', 'file_sexp', 'file_rexp', 'file_nd', 'file_sctr']]
    elif metric == 'product':
        X = X.drop(['file_la', 'file_ld', 'file_lt', 'file_age', 'file_ddev',
       'file_nuc', 'own', 'minor', 'file_ndev', 'file_ncomm', 'file_adev',
       'file_nadev', 'file_avg_nddev', 'file_avg_nadev', 'file_avg_ncomm',
       'file_ns', 'file_exp', 'file_sexp', 'file_rexp', 'file_nd', 'file_sctr'],axis = 1)
    else:
        X = X
    return X,y


def load_data_commit_level(project,metric):
    understand_path = 'data/understand_files_all/' + project + '_understand.csv'
    understand_df = pd.read_csv(understand_path)
    understand_df = understand_df.dropna(axis = 1,how='all')
    cols_list = understand_df.columns.values.tolist()
    for item in ['Kind', 'Name','commit_hash', 'Bugs']:
        if item in cols_list:
            cols_list.remove(item)
            cols_list.insert(0,item)
    understand_df = understand_df[cols_list]
    cols = understand_df.columns.tolist()
    understand_df = understand_df.drop_duplicates(cols[4:len(cols)])
    understand_df['Name'] = understand_df.Name.str.rsplit('.',1).str[1]
    
    commit_guru_file_level_path = 'data/commit_guru_file_level/' + project + '_file.csv'
    commit_guru_file_level_df = pd.read_csv(commit_guru_file_level_path)
    commit_guru_file_level_df['commit_hash'] = commit_guru_file_level_df.commit_hash.str.strip('"')
    commit_guru_file_level_df = commit_guru_file_level_df[commit_guru_file_level_df['file_name'].str.contains('.java')]
    commit_guru_file_level_df['Name'] = commit_guru_file_level_df.file_name.str.rsplit('/',1).str[1].str.split('.').str[0].str.replace('/','.')
    commit_guru_file_level_df = commit_guru_file_level_df.drop('file_name',axis = 1)
    
    
    df = understand_df.merge(commit_guru_file_level_df,how='left',on=['commit_hash','Name'])
    
    
    cols = df.columns.tolist()
    cols.remove('Bugs')
    cols.append('Bugs')
    df = df[cols]
    commit_hash = df.commit_hash
    for item in ['Kind', 'Name','commit_hash']:
        if item in cols:
            df = df.drop(labels = [item],axis=1)
#     df.dropna(inplace=True)
    df = df.drop_duplicates()
    df.reset_index(drop=True, inplace=True)
    
    y = df.Bugs
    X = df.drop('Bugs',axis = 1)
    cols = X.columns
    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)
    X = pd.DataFrame(X,columns = cols)
    imp_mean = IterativeImputer(random_state=0)
    X = imp_mean.fit_transform(X)
    X = pd.DataFrame(X,columns = cols)
    
    if metric == 'process':
        X = X[['la', 'ld', 'lt', 'age', 'ndev', 'nuc', 'ns', 'exp', 'sexp', 'rexp', 'nd']]
    elif metric == 'product':
        X = X.drop(['la', 'ld', 'lt', 'age', 'ndev', 'nuc', 'ns', 'exp', 'sexp', 'rexp', 'nd'],axis = 1)
    else:
        X = X
    
    df = X
    df['Bugs'] = y
    df['commit_hash'] = commit_hash
    unique_commits = df.commit_hash.unique()
    
    train_df = df[df.commit_hash.isin(unique_commits[0:int(len(unique_commits)*.6)])]
    test_df = df[df.commit_hash.isin(unique_commits[int(len(unique_commits)*.6):])]
    
    train_df.reset_index(inplace=True, drop=True)
    test_df.reset_index(inplace=True, drop=True)
    train_y = train_df.Bugs
    train_X = train_df.drop(['Bugs','commit_hash'],axis = 1)
    
    return train_X,train_y,test_df

# %%
def run_self_release(project,metric):
    precision = []
    recall = []
    pf = []
    f1 = []
    g_score = []
    auc = []
    pci_20 = []
    ifa = []
    X_train,y_train,test_df = load_data_commit_level(project,metric)      
    df_smote = pd.concat([X_train,y_train],axis = 1)
    df_smote = apply_smote(df_smote)
    y_train = df_smote.Bugs
    X_train = df_smote.drop('Bugs',axis = 1)
    clf =  RandomForestClassifier()
    clf.fit(X_train,y_train)
    importance = clf.feature_importances_
    unique_commits_list = np.array_split(test_df.commit_hash.unique(), 5)
    for i in range(len(unique_commits_list)):
        test_df_subset = test_df[test_df.commit_hash.isin(unique_commits_list[i])]
        y_test = test_df_subset.Bugs
        X_test = test_df_subset.drop(['Bugs','commit_hash'],axis = 1)
        if metric == 'process':
            loc = X_test['la'] + X_test['lt']
        elif metric == 'product':
            loc = X_test.CountLineCode
        else:
            loc = X_test['la'] + X_test['lt']                 
        predicted = clf.predict(X_test)
        abcd = metrices.measures(y_test,predicted,loc)
        pf.append(abcd.get_pf())
        recall.append(abcd.calculate_recall())
        precision.append(abcd.calculate_precision())
        f1.append(abcd.calculate_f1_score())
        g_score.append(abcd.get_g_score())
        pci_20.append(abcd.get_pci_20())
        ifa.append(abcd.get_ifa())
        try:
            auc.append(roc_auc_score(y_test, predicted))
        except:
            auc.append(0)
        print(classification_report(y_test, predicted))
#         print(recall,precision,pf,f1,g_score,auc,pci_20)
    return recall,precision,pf,f1,g_score,auc,pci_20,ifa,importance

# %%
def run_self_k(project,metric):
    precision = []
    recall = []
    pf = []
    f1 = []
    g_score = []
    auc = []
    pci_20 = []
    ifa = []
    importance = []
    X,y = load_both_data(project,metric)
    for _ in range(5):
        skf = StratifiedKFold(n_splits=5)
        for train_index, test_index in skf.split(X, y):
            X_train, X_test = X.loc[train_index], X.loc[test_index]
            y_train, y_test = y.loc[train_index], y.loc[test_index]
            if metric == 'process':
                loc = X_test['file_la'] + X_test['file_lt']
            elif metric == 'product':
                loc = X_test.CountLineCode
            else:
                loc = X_test['file_la'] + X_test['file_lt']
            df_smote = pd.concat([X_train,y_train],axis = 1)
            df_smote = apply_smote(df_smote)
            y_train = df_smote.Bugs
            X_train = df_smote.drop('Bugs',axis = 1)
            clf = SVC()
            clf.fit(X_train,y_train)
            importance = 0
            predicted = clf.predict(X_test)
            abcd = metrices.measures(y_test,predicted,loc)
            pf.append(abcd.get_pf())
            recall.append(abcd.calculate_recall())
            precision.append(abcd.calculate_precision())
            f1.append(abcd.calculate_f1_score())
            g_score.append(abcd.get_g_score())
            pci_20.append(abcd.get_pci_20())
            ifa.append(abcd.get_ifa())
            try:
                auc.append(roc_auc_score(y_test, predicted))
            except:
                auc.append(0)
#             print(classification_report(y_test, predicted))
    return recall,precision,pf,f1,g_score,auc,pci_20,ifa,importance

# %%
def run_self(project,metric):
    X,y = load_both_data(project,metric)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=18)
    if metric == 'process':
        loc = X_test['la'] + X_test['lt']
    elif metric == 'product':
        loc = X_test.CountLineCode
    else:
        loc = X_test['la'] + X_test['lt']
    df_smote = pd.concat([X_train,y_train],axis = 1)
    df_smote = apply_smote(df_smote)
    y_train = df_smote.Bugs
    X_train = df_smote.drop('Bugs',axis = 1)
    clf = RandomForestClassifier()
    clf.fit(X_train,y_train)
    importance = clf.feature_importances_
    print(len(importance))
    predicted = clf.predict(X_test)
    abcd = metrices.measures(y_test,predicted,loc)
    pf = abcd.get_pf()
    recall = abcd.calculate_recall()
    precision = abcd.calculate_precision()
    f1 = abcd.calculate_f1_score()
    g_score = abcd.get_g_score()
    pci_20 = abcd.get_pci_20()
    ifa = abcd.get_ifa()
    try:
        auc = roc_auc_score(y_test, predicted)
    except:
        auc = 0
    print(classification_report(y_test, predicted))
    return recall,precision,pf,f1,g_score,auc,pci_20,ifa,importance

# %%
proj_df = pd.read_csv('projects.csv')
projects = proj_df.repo_name.tolist()

# %%
precision_list = {}
recall_list = {}
pf_list = {}
f1_list = {}
g_list = {}
auc_list = {}
pci_20_list = {}
ifa_list = {}
featue_importance = {}
for project in projects[150:]:
    try:
        if project == '.DS_Store':
            continue
        print("+++++++++++++++++   "  + project + "  +++++++++++++++++")
        recall,precision,pf,f1,g_score,auc,pci_20,ifa,importance = run_self_k(project,'process+product')
        recall_list[project] = recall
        precision_list[project] = precision
        pf_list[project] = pf
        f1_list[project] = f1
        g_list[project] = g_score
        auc_list[project] = auc
        pci_20_list[project] = pci_20
        ifa_list[project] = ifa
        featue_importance[project] = importance
    except Exception as e:
        print(e)
        continue
final_result = {}
final_result['precision'] = precision_list
final_result['recall'] = recall_list
final_result['pf'] = pf_list
final_result['f1'] = f1_list
final_result['g'] = g_list
final_result['auc'] = auc_list
final_result['pci_20'] = pci_20_list
final_result['ifa'] = ifa_list
final_result['featue_importance'] = featue_importance
# Out:
# +++++++++++++++++   spring-xd-samples  +++++++++++++++++
# Shape of passed values is (62, 45), indices imply (62, 66)
# +++++++++++++++++   environment-dashboard  +++++++++++++++++
# +++++++++++++++++   plantuml  +++++++++++++++++
# +++++++++++++++++   egads  +++++++++++++++++
# +++++++++++++++++   dockerfile-maven  +++++++++++++++++
# +++++++++++++++++   android-pdfview  +++++++++++++++++
# +++++++++++++++++   rebound  +++++++++++++++++
# +++++++++++++++++   react-native-background-timer  +++++++++++++++++
# +++++++++++++++++   android-rss  +++++++++++++++++
# +++++++++++++++++   logback-kafka-appender  +++++++++++++++++
# +++++++++++++++++   Droppy  +++++++++++++++++
# +++++++++++++++++   RxActivityResult  +++++++++++++++++
# +++++++++++++++++   smart-show  +++++++++++++++++
# +++++++++++++++++   PatternLock  +++++++++++++++++
# +++++++++++++++++   RxHttpUtils  +++++++++++++++++
# +++++++++++++++++   android-transcoder  +++++++++++++++++
# +++++++++++++++++   pcollections  +++++++++++++++++
# +++++++++++++++++   libsignal-protocol-java  +++++++++++++++++
# +++++++++++++++++   ESPlorer  +++++++++++++++++
# +++++++++++++++++   geofire-java  +++++++++++++++++
# +++++++++++++++++   CircularReveal  +++++++++++++++++
# +++++++++++++++++   ABAGAIL  +++++++++++++++++
# +++++++++++++++++   react-native-splash-screen  +++++++++++++++++
# +++++++++++++++++   react-native-incall-manager  +++++++++++++++++
# +++++++++++++++++   libsignal-service-java  +++++++++++++++++
# +++++++++++++++++   MarkdownView  +++++++++++++++++
# +++++++++++++++++   dcevm  +++++++++++++++++
# +++++++++++++++++   wycheproof  +++++++++++++++++
# +++++++++++++++++   facebook-java-business-sdk  +++++++++++++++++
# +++++++++++++++++   FastDFS_Client  +++++++++++++++++
# +++++++++++++++++   jgit  +++++++++++++++++
# No columns to parse from file
# +++++++++++++++++   Telecine  +++++++++++++++++
# +++++++++++++++++   Bolts-Android  +++++++++++++++++
# +++++++++++++++++   jieba-analysis  +++++++++++++++++
# +++++++++++++++++   gcm  +++++++++++++++++
# +++++++++++++++++   android-app  +++++++++++++++++
# No columns to parse from file
# +++++++++++++++++   Android-RateThisApp  +++++++++++++++++
# +++++++++++++++++   RESTMock  +++++++++++++++++
# +++++++++++++++++   poster-generater  +++++++++++++++++
# +++++++++++++++++   pandora  +++++++++++++++++
# +++++++++++++++++   BottomSheetBuilder  +++++++++++++++++
# Shape of passed values is (77, 45), indices imply (77, 66)
# +++++++++++++++++   progressbar  +++++++++++++++++
# +++++++++++++++++   android-sliding-layer-lib  +++++++++++++++++
# +++++++++++++++++   ASNE  +++++++++++++++++
# +++++++++++++++++   binnavi  +++++++++++++++++
# +++++++++++++++++   TapTargetView  +++++++++++++++++
# +++++++++++++++++   community  +++++++++++++++++
# Shape of passed values is (62, 45), indices imply (62, 66)
# +++++++++++++++++   android-floating-action-button  +++++++++++++++++
# +++++++++++++++++   RxCache  +++++++++++++++++
# +++++++++++++++++   EasyRefreshLayout  +++++++++++++++++
# +++++++++++++++++   HwTxtReader  +++++++++++++++++
# +++++++++++++++++   Recyclerview-Gallery  +++++++++++++++++
# +++++++++++++++++   SandVXposed  +++++++++++++++++
# +++++++++++++++++   moditect  +++++++++++++++++
# +++++++++++++++++   clean-status-bar  +++++++++++++++++
# +++++++++++++++++   react-native-geolocation-service  +++++++++++++++++
# +++++++++++++++++   DynamicGrid  +++++++++++++++++
# +++++++++++++++++   bottomsheet  +++++++++++++++++
# +++++++++++++++++   seata-samples  +++++++++++++++++
# +++++++++++++++++   HomeMirror  +++++++++++++++++
# +++++++++++++++++   emojicon  +++++++++++++++++
# +++++++++++++++++   otto  +++++++++++++++++
# +++++++++++++++++   ip2region  +++++++++++++++++
# +++++++++++++++++   native-navigation  +++++++++++++++++
# +++++++++++++++++   joda-time-android  +++++++++++++++++
# +++++++++++++++++   ExpandableTextView  +++++++++++++++++
# +++++++++++++++++   Reservoir  +++++++++++++++++
# +++++++++++++++++   tinybus  +++++++++++++++++
# +++++++++++++++++   EasyNavigation  +++++++++++++++++
# +++++++++++++++++   RxFingerprint  +++++++++++++++++
# +++++++++++++++++   react-native-background-job  +++++++++++++++++
# +++++++++++++++++   modernizer-maven-plugin  +++++++++++++++++
# +++++++++++++++++   Launcher  +++++++++++++++++
# +++++++++++++++++   gs-uploading-files  +++++++++++++++++
# Shape of passed values is (32, 45), indices imply (32, 66)
# +++++++++++++++++   android-flowlayout  +++++++++++++++++
# +++++++++++++++++   dbeaver  +++++++++++++++++
# +++++++++++++++++   android-mvp-architecture  +++++++++++++++++
# +++++++++++++++++   otter  +++++++++++++++++
# +++++++++++++++++   AlphabetIndex-Fast-Scroll-RecyclerView  +++++++++++++++++
# +++++++++++++++++   CalendarFX  +++++++++++++++++
# +++++++++++++++++   knife  +++++++++++++++++
# +++++++++++++++++   StepView  +++++++++++++++++
# +++++++++++++++++   Space-Navigation-View  +++++++++++++++++
# +++++++++++++++++   mqtt-client  +++++++++++++++++
# +++++++++++++++++   emoji-java  +++++++++++++++++
# +++++++++++++++++   reflections  +++++++++++++++++
# +++++++++++++++++   databus  +++++++++++++++++
# +++++++++++++++++   Once  +++++++++++++++++
# +++++++++++++++++   easygcm  +++++++++++++++++
# +++++++++++++++++   ion-java  +++++++++++++++++
# +++++++++++++++++   SoLoader  +++++++++++++++++
# +++++++++++++++++   UpdateChecker  +++++++++++++++++
# +++++++++++++++++   aho-corasick  +++++++++++++++++
# +++++++++++++++++   Android-ReactiveLocation  +++++++++++++++++
# +++++++++++++++++   gradle-retrolambda  +++++++++++++++++
# +++++++++++++++++   SmoothProgressBar  +++++++++++++++++
# +++++++++++++++++   JustAuth  +++++++++++++++++
# +++++++++++++++++   arara  +++++++++++++++++
# Shape of passed values is (244, 45), indices imply (244, 66)
# +++++++++++++++++   swipe-button  +++++++++++++++++
# +++++++++++++++++   react-native-intercom  +++++++++++++++++
# +++++++++++++++++   ShapeOfView  +++++++++++++++++
# +++++++++++++++++   KenBurnsView  +++++++++++++++++
# +++++++++++++++++   MaterialShowcaseView  +++++++++++++++++
# +++++++++++++++++   ImageViewZoom  +++++++++++++++++
# +++++++++++++++++   CreditCardEntry  +++++++++++++++++
# +++++++++++++++++   Qigsaw  +++++++++++++++++
# +++++++++++++++++   SuperAdapter  +++++++++++++++++
# Shape of passed values is (127, 45), indices imply (127, 66)
# +++++++++++++++++   DaggerMock  +++++++++++++++++
# +++++++++++++++++   Fast-Android-Networking  +++++++++++++++++
# +++++++++++++++++   ListItemView  +++++++++++++++++
# +++++++++++++++++   busybox  +++++++++++++++++
# +++++++++++++++++   react-native-dialogs  +++++++++++++++++
# +++++++++++++++++   android-material-design-icon-generator-plugin  +++++++++++++++++
# [Errno 2] File data/commit_guru_file/android-material-design-icon-generator-plugin.csv does not exist: 'data/commit_guru_file/android-material-design-icon-generator-plugin.csv'
# +++++++++++++++++   DataflowTemplates  +++++++++++++++++
# +++++++++++++++++   the-app  +++++++++++++++++
# +++++++++++++++++   glide-transformations  +++++++++++++++++
# +++++++++++++++++   X2C  +++++++++++++++++
# +++++++++++++++++   Android-DirectoryChooser  +++++++++++++++++
# +++++++++++++++++   jdeferred  +++++++++++++++++
# +++++++++++++++++   RxBluetooth  +++++++++++++++++
# +++++++++++++++++   react-native-calendar-events  +++++++++++++++++
# +++++++++++++++++   cordova-plugin-admob-free  +++++++++++++++++
# The number of classes has to be greater than one; got 1 class
# +++++++++++++++++   sofa-tracer  +++++++++++++++++
# +++++++++++++++++   react-native-touch-id  +++++++++++++++++
# +++++++++++++++++   linuxdeploy  +++++++++++++++++
# +++++++++++++++++   brickhouse  +++++++++++++++++
# +++++++++++++++++   FinestWebView-Android  +++++++++++++++++
# +++++++++++++++++   tut-spring-boot-oauth2  +++++++++++++++++
# +++++++++++++++++   android-viewflow  +++++++++++++++++
# +++++++++++++++++   s3s3mirror  +++++++++++++++++
# +++++++++++++++++   header-decor  +++++++++++++++++
# +++++++++++++++++   WeatherLib  +++++++++++++++++
# +++++++++++++++++   hppc  +++++++++++++++++
# +++++++++++++++++   spring-javaformat  +++++++++++++++++
# +++++++++++++++++   JSONassert  +++++++++++++++++
# Shape of passed values is (102, 45), indices imply (102, 66)
# +++++++++++++++++   secure-preferences  +++++++++++++++++
# +++++++++++++++++   esb-connectors  +++++++++++++++++
# +++++++++++++++++   Quicksql  +++++++++++++++++
# +++++++++++++++++   cordova-plugin-googleplus  +++++++++++++++++
# The number of classes has to be greater than one; got 1 class
# +++++++++++++++++   jacoco  +++++++++++++++++
# Shape of passed values is (1037, 45), indices imply (1037, 66)
# +++++++++++++++++   FloatingActionButton  +++++++++++++++++
# +++++++++++++++++   pinned-section-listview  +++++++++++++++++
# +++++++++++++++++   dynamic-load-apk  +++++++++++++++++
# +++++++++++++++++   elasticsearch-analysis-ik  +++++++++++++++++
# +++++++++++++++++   jersey  +++++++++++++++++
# Shape of passed values is (5148, 45), indices imply (5148, 66)
# +++++++++++++++++   corretto-8  +++++++++++++++++
# Shape of passed values is (39687, 45), indices imply (39687, 66)
# +++++++++++++++++   CustomBottomSheetBehavior  +++++++++++++++++
# +++++++++++++++++   Pydev  +++++++++++++++++
# Shape of passed values is (2269, 45), indices imply (2269, 66)
# +++++++++++++++++   MultiImagePicker  +++++++++++++++++
# +++++++++++++++++   spring-test-dbunit  +++++++++++++++++
# +++++++++++++++++   AndroidTraining  +++++++++++++++++
# +++++++++++++++++   browsermob-proxy  +++++++++++++++++
# +++++++++++++++++   android-state  +++++++++++++++++
# +++++++++++++++++   uber-apk-signer  +++++++++++++++++
# +++++++++++++++++   SocialSdkLibrary  +++++++++++++++++
# +++++++++++++++++   app-icon  +++++++++++++++++
# Shape of passed values is (89, 45), indices imply (89, 66)
# +++++++++++++++++   pacbot  +++++++++++++++++
# +++++++++++++++++   react-native-keychain  +++++++++++++++++
# Shape of passed values is (40, 45), indices imply (40, 66)
# +++++++++++++++++   hbc  +++++++++++++++++
# +++++++++++++++++   sticky-headers-recyclerview  +++++++++++++++++
# +++++++++++++++++   AndroidPerformanceMonitor  +++++++++++++++++
# +++++++++++++++++   hmily  +++++++++++++++++
# +++++++++++++++++   colorpicker  +++++++++++++++++
# +++++++++++++++++   material-calendar-view  +++++++++++++++++
# +++++++++++++++++   eo  +++++++++++++++++
# Shape of passed values is (160, 45), indices imply (160, 66)
# +++++++++++++++++   aws-ec2-ssh  +++++++++++++++++
# +++++++++++++++++   react-native-youtube  +++++++++++++++++
# +++++++++++++++++   Calligraphy  +++++++++++++++++
# +++++++++++++++++   packr  +++++++++++++++++
# +++++++++++++++++   termux-api  +++++++++++++++++
# +++++++++++++++++   HtmlSpanner  +++++++++++++++++
# +++++++++++++++++   android-contentprovider-generator  +++++++++++++++++
# +++++++++++++++++   javafx-gradle-plugin  +++++++++++++++++
# +++++++++++++++++   openstego  +++++++++++++++++
# +++++++++++++++++   RxJavaFX  +++++++++++++++++
# +++++++++++++++++   google-oauth-java-client  +++++++++++++++++
# +++++++++++++++++   Hacktoberfest-Mathematics  +++++++++++++++++
# Shape of passed values is (54, 45), indices imply (54, 66)
# +++++++++++++++++   zkclient  +++++++++++++++++
# +++++++++++++++++   airline  +++++++++++++++++
# +++++++++++++++++   ncalc  +++++++++++++++++
# +++++++++++++++++   react-native-google-places  +++++++++++++++++
# +++++++++++++++++   Android-Rich-text-Editor  +++++++++++++++++
# +++++++++++++++++   opencv-processing  +++++++++++++++++
# +++++++++++++++++   QRCodeReaderView  +++++++++++++++++
# +++++++++++++++++   FizzBuzzEnterpriseEdition  +++++++++++++++++
# +++++++++++++++++   gpmall  +++++++++++++++++
# +++++++++++++++++   openhab1-addons  +++++++++++++++++
# +++++++++++++++++   re2j  +++++++++++++++++
# +++++++++++++++++   mortar  +++++++++++++++++
# +++++++++++++++++   vertx-sql-client  +++++++++++++++++
# +++++++++++++++++   groupie  +++++++++++++++++
# +++++++++++++++++   UrlImageViewHelper  +++++++++++++++++
# +++++++++++++++++   jgit-cookbook  +++++++++++++++++
# +++++++++++++++++   ice  +++++++++++++++++
# +++++++++++++++++   dashboard-demo  +++++++++++++++++
# +++++++++++++++++   qmq  +++++++++++++++++
# +++++++++++++++++   Paper  +++++++++++++++++
# +++++++++++++++++   OpenNoteScanner  +++++++++++++++++
# +++++++++++++++++   plantuml-server  +++++++++++++++++
# +++++++++++++++++   openiot  +++++++++++++++++
# Shape of passed values is (1979, 45), indices imply (1979, 66)
# +++++++++++++++++   MultiViewAdapter  +++++++++++++++++
# +++++++++++++++++   tape  +++++++++++++++++
# +++++++++++++++++   Leonids  +++++++++++++++++
# +++++++++++++++++   react-native-admob  +++++++++++++++++
# Shape of passed values is (86, 45), indices imply (86, 66)
# +++++++++++++++++   dialogplus  +++++++++++++++++
# +++++++++++++++++   jstorm  +++++++++++++++++
# +++++++++++++++++   groovy-eclipse  +++++++++++++++++
# Shape of passed values is (22915, 45), indices imply (22915, 66)
# +++++++++++++++++   Router  +++++++++++++++++
# +++++++++++++++++   RIBs  +++++++++++++++++
# +++++++++++++++++   kafka-streams-examples  +++++++++++++++++
# +++++++++++++++++   react-native-push-notification  +++++++++++++++++
# +++++++++++++++++   t-digest  +++++++++++++++++
# +++++++++++++++++   Android-Rate  +++++++++++++++++
# +++++++++++++++++   instagram4j  +++++++++++++++++
# +++++++++++++++++   android-test  +++++++++++++++++
# +++++++++++++++++   react-native-sensitive-info  +++++++++++++++++
# +++++++++++++++++   quarkus-quickstarts  +++++++++++++++++
# +++++++++++++++++   nice-spinner  +++++++++++++++++
# +++++++++++++++++   UsbSerial  +++++++++++++++++
# +++++++++++++++++   cordova-crosswalk-engine  +++++++++++++++++
# +++++++++++++++++   ahbottomnavigation  +++++++++++++++++
# +++++++++++++++++   lottie-react-native  +++++++++++++++++
# +++++++++++++++++   ThinDownloadManager  +++++++++++++++++
# +++++++++++++++++   react-native-bottom-sheet-behavior  +++++++++++++++++
# +++++++++++++++++   loklak_wok_android  +++++++++++++++++
# Shape of passed values is (201, 45), indices imply (201, 66)
# +++++++++++++++++   rocker  +++++++++++++++++
# +++++++++++++++++   droid-fu  +++++++++++++++++
# +++++++++++++++++   react-native-picker  +++++++++++++++++
# +++++++++++++++++   DebugDrawer  +++++++++++++++++
# +++++++++++++++++   android_packages_apps_UnifiedNlp  +++++++++++++++++
# +++++++++++++++++   walt  +++++++++++++++++
# +++++++++++++++++   problem  +++++++++++++++++
# +++++++++++++++++   SpringCloud  +++++++++++++++++
# +++++++++++++++++   jira-client  +++++++++++++++++
# +++++++++++++++++   Hive-JSON-Serde  +++++++++++++++++
# +++++++++++++++++   react-native-google-signin  +++++++++++++++++
# +++++++++++++++++   socket.io-client-java  +++++++++++++++++
# +++++++++++++++++   DroidPlugin  +++++++++++++++++
# +++++++++++++++++   TagMo  +++++++++++++++++
# +++++++++++++++++   android-transition  +++++++++++++++++
# +++++++++++++++++   AndroidJSCore  +++++++++++++++++
# +++++++++++++++++   LicensesDialog  +++++++++++++++++
# +++++++++++++++++   tomighty  +++++++++++++++++
# +++++++++++++++++   hawk  +++++++++++++++++
# +++++++++++++++++   AndResGuard  +++++++++++++++++
# +++++++++++++++++   ShortcutBadger  +++++++++++++++++
# +++++++++++++++++   addressbook-level2  +++++++++++++++++
# Shape of passed values is (215, 45), indices imply (215, 66)
# +++++++++++++++++   storm-yarn  +++++++++++++++++
# +++++++++++++++++   ea-async  +++++++++++++++++
# +++++++++++++++++   ReactiveNetwork  +++++++++++++++++
# +++++++++++++++++   start.spring.io  +++++++++++++++++
# +++++++++++++++++   docker-workflow-plugin  +++++++++++++++++
# +++++++++++++++++   storm-contrib  +++++++++++++++++
# +++++++++++++++++   android-iconify  +++++++++++++++++
# +++++++++++++++++   Luyten  +++++++++++++++++
# +++++++++++++++++   ViewPagerIndicator  +++++++++++++++++
# +++++++++++++++++   nitrite-database  +++++++++++++++++
# +++++++++++++++++   limbo  +++++++++++++++++
# Shape of passed values is (1008, 45), indices imply (1008, 66)
# +++++++++++++++++   kafkahq  +++++++++++++++++
# +++++++++++++++++   snackbar  +++++++++++++++++
# +++++++++++++++++   react-native-baidu-map  +++++++++++++++++
# Shape of passed values is (149, 45), indices imply (149, 66)
# +++++++++++++++++   kafka-connect-elasticsearch  +++++++++++++++++
# +++++++++++++++++   neurolab-android  +++++++++++++++++
# +++++++++++++++++   soul  +++++++++++++++++
# +++++++++++++++++   jmx_exporter  +++++++++++++++++
# +++++++++++++++++   RecyclerViewPager  +++++++++++++++++
# +++++++++++++++++   ChatKit  +++++++++++++++++
# +++++++++++++++++   jvm-sandbox  +++++++++++++++++
# +++++++++++++++++   android-crop  +++++++++++++++++
# +++++++++++++++++   quartz  +++++++++++++++++
# Shape of passed values is (1253, 45), indices imply (1253, 66)
# +++++++++++++++++   jenkins-gitlab-merge-request-builder-plugin  +++++++++++++++++
# +++++++++++++++++   TextJustify-Android  +++++++++++++++++
# +++++++++++++++++   PhotoPicker  +++++++++++++++++
# Shape of passed values is (244, 45), indices imply (244, 66)
# +++++++++++++++++   jjwt  +++++++++++++++++
# +++++++++++++++++   Android-Week-View  +++++++++++++++++
# +++++++++++++++++   rejoiner  +++++++++++++++++
# +++++++++++++++++   react-native-screens  +++++++++++++++++
# Shape of passed values is (96, 45), indices imply (96, 66)
# +++++++++++++++++   react-native-sqlite-storage  +++++++++++++++++
# +++++++++++++++++   HTTP-Proxy-Servlet  +++++++++++++++++
# +++++++++++++++++   react-native-sound  +++++++++++++++++
# +++++++++++++++++   subsampling-scale-image-view  +++++++++++++++++
# +++++++++++++++++   sofa-boot  +++++++++++++++++
# +++++++++++++++++   Lynx  +++++++++++++++++
# Shape of passed values is (204, 45), indices imply (204, 66)
# +++++++++++++++++   storage-chooser  +++++++++++++++++
# +++++++++++++++++   js-graphql-intellij-plugin  +++++++++++++++++
# +++++++++++++++++   merlin  +++++++++++++++++
# +++++++++++++++++   react-native-oauth  +++++++++++++++++
# +++++++++++++++++   parceler  +++++++++++++++++
# +++++++++++++++++   react-native-background-geolocation  +++++++++++++++++
# +++++++++++++++++   AppAuth-Android  +++++++++++++++++
# +++++++++++++++++   binding-collection-adapter  +++++++++++++++++
# +++++++++++++++++   Amadeus  +++++++++++++++++
# +++++++++++++++++   dns66  +++++++++++++++++
# +++++++++++++++++   consul-api  +++++++++++++++++
# +++++++++++++++++   TarsosDSP  +++++++++++++++++
# +++++++++++++++++   spring-cloud-stream-samples  +++++++++++++++++
# +++++++++++++++++   HTextView  +++++++++++++++++
# +++++++++++++++++   dubbo-spring-boot-project  +++++++++++++++++
# +++++++++++++++++   kumo  +++++++++++++++++
# +++++++++++++++++   hn-android  +++++++++++++++++
# +++++++++++++++++   coffee-gb  +++++++++++++++++
# +++++++++++++++++   postgresql-embedded  +++++++++++++++++
# +++++++++++++++++   spring-loaded  +++++++++++++++++
# +++++++++++++++++   truetime-android  +++++++++++++++++
# +++++++++++++++++   Flashtool  +++++++++++++++++
# +++++++++++++++++   flutter_boost  +++++++++++++++++
# +++++++++++++++++   flutter_webview_plugin  +++++++++++++++++
# +++++++++++++++++   android-basic-samples  +++++++++++++++++
# +++++++++++++++++   infinitest  +++++++++++++++++
# +++++++++++++++++   FastLib  +++++++++++++++++
# +++++++++++++++++   MaterialScrollBar  +++++++++++++++++
# +++++++++++++++++   react-native-audio-toolkit  +++++++++++++++++
# +++++++++++++++++   Superuser  +++++++++++++++++
# +++++++++++++++++   netbeans  +++++++++++++++++
# Shape of passed values is (82653, 45), indices imply (82653, 66)
# +++++++++++++++++   ActiveAndroid  +++++++++++++++++
# +++++++++++++++++   j2html  +++++++++++++++++
# +++++++++++++++++   img2latex-mathpix  +++++++++++++++++
# Shape of passed values is (102, 45), indices imply (102, 66)
# +++++++++++++++++   kryonet  +++++++++++++++++
# +++++++++++++++++   react-native-app-auth  +++++++++++++++++
# +++++++++++++++++   TextFieldBoxes  +++++++++++++++++
# +++++++++++++++++   fragmentargs  +++++++++++++++++
# Shape of passed values is (70, 45), indices imply (70, 66)
# +++++++++++++++++   freeline  +++++++++++++++++
# +++++++++++++++++   wasp  +++++++++++++++++
# +++++++++++++++++   cling  +++++++++++++++++
# +++++++++++++++++   sonar-gitlab-plugin  +++++++++++++++++
# +++++++++++++++++   android_additive_animations  +++++++++++++++++
# +++++++++++++++++   screenshot-tests-for-android  +++++++++++++++++
# +++++++++++++++++   java-telegram-bot-api  +++++++++++++++++
# +++++++++++++++++   golo-lang  +++++++++++++++++
# +++++++++++++++++   kura  +++++++++++++++++
# +++++++++++++++++   tray  +++++++++++++++++
# Shape of passed values is (193, 45), indices imply (193, 66)
# +++++++++++++++++   postgres-async-driver  +++++++++++++++++
# +++++++++++++++++   spring-cloud-security  +++++++++++++++++
# +++++++++++++++++   MaterialEditText  +++++++++++++++++
# +++++++++++++++++   cm_api  +++++++++++++++++
# Shape of passed values is (257, 45), indices imply (257, 66)
# +++++++++++++++++   leveldb  +++++++++++++++++
# +++++++++++++++++   libsuperuser  +++++++++++++++++
# +++++++++++++++++   dubbo-admin  +++++++++++++++++
# +++++++++++++++++   cardslib  +++++++++++++++++
# Shape of passed values is (1598, 45), indices imply (1598, 66)
# +++++++++++++++++   EvalEx  +++++++++++++++++
# +++++++++++++++++   react-native-music-control  +++++++++++++++++
# +++++++++++++++++   gradle-download-task  +++++++++++++++++
# +++++++++++++++++   apk-parser  +++++++++++++++++
# +++++++++++++++++   sendgrid-java  +++++++++++++++++
# +++++++++++++++++   Caldroid  +++++++++++++++++
# +++++++++++++++++   google-authenticator  +++++++++++++++++
# +++++++++++++++++   VasSonic  +++++++++++++++++
# +++++++++++++++++   jInstagram  +++++++++++++++++
# +++++++++++++++++   Emoji  +++++++++++++++++
# Shape of passed values is (500, 45), indices imply (500, 66)
# +++++++++++++++++   jbot  +++++++++++++++++
# +++++++++++++++++   algos  +++++++++++++++++
# Shape of passed values is (63, 45), indices imply (63, 66)
# +++++++++++++++++   termux-app  +++++++++++++++++
# +++++++++++++++++   atom  +++++++++++++++++
# +++++++++++++++++   RxPermissions  +++++++++++++++++
# +++++++++++++++++   AndroidPicker  +++++++++++++++++
# +++++++++++++++++   concurrency-limits  +++++++++++++++++
# Shape of passed values is (455, 45), indices imply (455, 66)
# +++++++++++++++++   Android-CircleDialog  +++++++++++++++++
# +++++++++++++++++   Dexter  +++++++++++++++++
# +++++++++++++++++   stream-lib  +++++++++++++++++
# +++++++++++++++++   java-jwt  +++++++++++++++++
# +++++++++++++++++   SingleDateAndTimePicker  +++++++++++++++++
# +++++++++++++++++   expandable-recycler-view  +++++++++++++++++
# +++++++++++++++++   aliyun-oss-java-sdk  +++++++++++++++++
# +++++++++++++++++   RoundedImageView  +++++++++++++++++
# +++++++++++++++++   android-volley  +++++++++++++++++
# +++++++++++++++++   Moxy  +++++++++++++++++
# +++++++++++++++++   aliyun-oss-android-sdk  +++++++++++++++++
# +++++++++++++++++   Shadow  +++++++++++++++++
# Shape of passed values is (294, 45), indices imply (294, 66)
# +++++++++++++++++   DragonProxy  +++++++++++++++++
# +++++++++++++++++   tikxml  +++++++++++++++++
# +++++++++++++++++   jenkins-build-monitor-plugin  +++++++++++++++++
# +++++++++++++++++   phonegap-nfc  +++++++++++++++++
# +++++++++++++++++   react-native-contacts  +++++++++++++++++
# +++++++++++++++++   sugar  +++++++++++++++++
# +++++++++++++++++   brigadier  +++++++++++++++++
# +++++++++++++++++   java-saml  +++++++++++++++++
# +++++++++++++++++   spring-retry  +++++++++++++++++
# +++++++++++++++++   map-matching  +++++++++++++++++
# +++++++++++++++++   material-intro  +++++++++++++++++
# +++++++++++++++++   android-vts  +++++++++++++++++
# +++++++++++++++++   android-saripaar  +++++++++++++++++
# +++++++++++++++++   archaius  +++++++++++++++++
# +++++++++++++++++   dubbo-samples  +++++++++++++++++
# +++++++++++++++++   Parse-SDK-Android  +++++++++++++++++
# +++++++++++++++++   sofa-rpc  +++++++++++++++++
# +++++++++++++++++   Small  +++++++++++++++++
# +++++++++++++++++   geometry-api-java  +++++++++++++++++
# +++++++++++++++++   Calendar-PhoneGap-Plugin  +++++++++++++++++
# +++++++++++++++++   SimpleCropView  +++++++++++++++++
# +++++++++++++++++   android-betterpickers  +++++++++++++++++
# +++++++++++++++++   arthas  +++++++++++++++++
# +++++++++++++++++   args4j  +++++++++++++++++
# +++++++++++++++++   java-diff-utils  +++++++++++++++++
# +++++++++++++++++   twitter-kit-android  +++++++++++++++++
# +++++++++++++++++   caelum-stella  +++++++++++++++++
# +++++++++++++++++   AndroidSlidingUpPanel  +++++++++++++++++
# +++++++++++++++++   stardroid  +++++++++++++++++
# +++++++++++++++++   intellij-plugin-save-actions  +++++++++++++++++
# +++++++++++++++++   dropbox-sdk-java  +++++++++++++++++
# +++++++++++++++++   iceberg  +++++++++++++++++
# +++++++++++++++++   material-remixer-android  +++++++++++++++++
# +++++++++++++++++   jackson-annotations  +++++++++++++++++
# +++++++++++++++++   sofa-ark  +++++++++++++++++
# +++++++++++++++++   LeetCode-Sol-Res  +++++++++++++++++
# Shape of passed values is (1170, 45), indices imply (1170, 66)
# +++++++++++++++++   NullAway  +++++++++++++++++
# +++++++++++++++++   easymock  +++++++++++++++++
# +++++++++++++++++   dialogflow-android-client  +++++++++++++++++
# Shape of passed values is (521, 45), indices imply (521, 66)
# +++++++++++++++++   mbassador  +++++++++++++++++
# +++++++++++++++++   TokenAutoComplete  +++++++++++++++++
# +++++++++++++++++   mysql-binlog-connector-java  +++++++++++++++++
# +++++++++++++++++   airpal  +++++++++++++++++
# +++++++++++++++++   cordova-plugin-background-mode  +++++++++++++++++
# The number of classes has to be greater than one; got 1 class
# +++++++++++++++++   awaitility  +++++++++++++++++
# +++++++++++++++++   amazon-kinesis-client  +++++++++++++++++
# +++++++++++++++++   react-native-share  +++++++++++++++++
# +++++++++++++++++   jhipster-registry  +++++++++++++++++
# Shape of passed values is (355, 45), indices imply (355, 66)
# +++++++++++++++++   ShowcaseView  +++++++++++++++++
# +++++++++++++++++   signal-cli  +++++++++++++++++
# +++++++++++++++++   zendesk-java-client  +++++++++++++++++
# +++++++++++++++++   crawler4j  +++++++++++++++++
# +++++++++++++++++   flow  +++++++++++++++++
# +++++++++++++++++   bnd  +++++++++++++++++
# +++++++++++++++++   blade  +++++++++++++++++
# +++++++++++++++++   java-object-diff  +++++++++++++++++
# +++++++++++++++++   opentracing-java  +++++++++++++++++
# +++++++++++++++++   CountryCodePickerProject  +++++++++++++++++
# +++++++++++++++++   Pedometer  +++++++++++++++++
# +++++++++++++++++   react-native-firestack  +++++++++++++++++
# +++++++++++++++++   AndrOBD  +++++++++++++++++
# +++++++++++++++++   dexmaker  +++++++++++++++++
# Shape of passed values is (723, 45), indices imply (723, 66)
# +++++++++++++++++   cosbench  +++++++++++++++++
# +++++++++++++++++   Markwon  +++++++++++++++++
# +++++++++++++++++   algorithms-sedgewick-wayne  +++++++++++++++++
# +++++++++++++++++   derive4j  +++++++++++++++++
# +++++++++++++++++   spring-cloud-task  +++++++++++++++++
# +++++++++++++++++   kayenta  +++++++++++++++++
# +++++++++++++++++   react-native-webview  +++++++++++++++++
# Shape of passed values is (107, 45), indices imply (107, 66)
# +++++++++++++++++   suro  +++++++++++++++++
# +++++++++++++++++   TableView  +++++++++++++++++
# Shape of passed values is (500, 45), indices imply (500, 66)
# +++++++++++++++++   jOOR  +++++++++++++++++
# +++++++++++++++++   greys-anatomy  +++++++++++++++++
# +++++++++++++++++   brpc-java  +++++++++++++++++
# +++++++++++++++++   otj-pg-embedded  +++++++++++++++++
# +++++++++++++++++   contrib-drivers  +++++++++++++++++
# Shape of passed values is (348, 45), indices imply (348, 66)
# +++++++++++++++++   EclipseCodeFormatter  +++++++++++++++++
# Shape of passed values is (486, 45), indices imply (486, 66)
# +++++++++++++++++   EdXposed  +++++++++++++++++
# +++++++++++++++++   apis  +++++++++++++++++
# +++++++++++++++++   camerakit-android  +++++++++++++++++
# +++++++++++++++++   Koloboke  +++++++++++++++++
# +++++++++++++++++   pf4j  +++++++++++++++++
# No columns to parse from file
# +++++++++++++++++   kafka-connect-hdfs  +++++++++++++++++
# +++++++++++++++++   AlgoDS  +++++++++++++++++
# +++++++++++++++++   Store  +++++++++++++++++
# +++++++++++++++++   moshi  +++++++++++++++++
# +++++++++++++++++   EventBus  +++++++++++++++++
# +++++++++++++++++   jOOL  +++++++++++++++++
# +++++++++++++++++   gdx-ai  +++++++++++++++++
# +++++++++++++++++   jaeger-client-java  +++++++++++++++++
# +++++++++++++++++   DeepLinkDispatch  +++++++++++++++++
# +++++++++++++++++   Pokemap  +++++++++++++++++
# +++++++++++++++++   butterknife  +++++++++++++++++
# +++++++++++++++++   gitflow4idea  +++++++++++++++++
# +++++++++++++++++   bigtop  +++++++++++++++++
# +++++++++++++++++   yuicompressor  +++++++++++++++++
# +++++++++++++++++   react-native-fcm  +++++++++++++++++
# +++++++++++++++++   MiPushFramework  +++++++++++++++++
# +++++++++++++++++   simple-slack-api  +++++++++++++++++
# +++++++++++++++++   circuitjs1  +++++++++++++++++
# +++++++++++++++++   exhibitor  +++++++++++++++++
# +++++++++++++++++   cqengine  +++++++++++++++++
# +++++++++++++++++   problem-spring-web  +++++++++++++++++
# +++++++++++++++++   Android-ObservableScrollView  +++++++++++++++++
# Shape of passed values is (651, 45), indices imply (651, 66)
# +++++++++++++++++   reactive-streams-jvm  +++++++++++++++++
# +++++++++++++++++   traccar-client-android  +++++++++++++++++
# +++++++++++++++++   jts  +++++++++++++++++
# +++++++++++++++++   PageIndicatorView  +++++++++++++++++
# +++++++++++++++++   polyglot  +++++++++++++++++
# +++++++++++++++++   cw-omnibus  +++++++++++++++++
# Shape of passed values is (3059, 45), indices imply (3059, 66)
# +++++++++++++++++   spring-cloud-zuul-ratelimit  +++++++++++++++++
# +++++++++++++++++   react-native-ble-manager  +++++++++++++++++
# +++++++++++++++++   nosql-unit  +++++++++++++++++
# +++++++++++++++++   frontend-maven-plugin  +++++++++++++++++
# +++++++++++++++++   farebot  +++++++++++++++++
# +++++++++++++++++   play-authenticate  +++++++++++++++++
# +++++++++++++++++   ForgeGradle  +++++++++++++++++
# +++++++++++++++++   aem-core-wcm-components  +++++++++++++++++
# +++++++++++++++++   getting-started-java  +++++++++++++++++
# +++++++++++++++++   bytecode-viewer  +++++++++++++++++
# +++++++++++++++++   disconf  +++++++++++++++++
# +++++++++++++++++   Much-Assembly-Required  +++++++++++++++++
# +++++++++++++++++   vulnerability-assessment-tool  +++++++++++++++++
# +++++++++++++++++   ffmpeg-cli-wrapper  +++++++++++++++++
# +++++++++++++++++   slack-plugin  +++++++++++++++++
# +++++++++++++++++   WaniKani-for-Android  +++++++++++++++++
# +++++++++++++++++   tabula-java  +++++++++++++++++
# +++++++++++++++++   OpenHub  +++++++++++++++++
# +++++++++++++++++   lz4-java  +++++++++++++++++
# +++++++++++++++++   cocos2d  +++++++++++++++++
# No columns to parse from file
# +++++++++++++++++   HdrHistogram  +++++++++++++++++
# +++++++++++++++++   json  +++++++++++++++++
# +++++++++++++++++   xmrwallet  +++++++++++++++++
# +++++++++++++++++   GeoSpark  +++++++++++++++++
# +++++++++++++++++   dr-elephant  +++++++++++++++++
# +++++++++++++++++   snappy-java  +++++++++++++++++
# +++++++++++++++++   Shizuku  +++++++++++++++++
# +++++++++++++++++   BannerViewPager  +++++++++++++++++
# +++++++++++++++++   typescript-generator  +++++++++++++++++
# +++++++++++++++++   pojobuilder  +++++++++++++++++
# +++++++++++++++++   elasticsearch-jdbc  +++++++++++++++++
# +++++++++++++++++   jolt  +++++++++++++++++
# +++++++++++++++++   logstash-logback-encoder  +++++++++++++++++
# +++++++++++++++++   github-plugin  +++++++++++++++++
# +++++++++++++++++   Android-DFU-Library  +++++++++++++++++
# +++++++++++++++++   yaxim  +++++++++++++++++
# +++++++++++++++++   javacv  +++++++++++++++++
# +++++++++++++++++   Guns  +++++++++++++++++
# +++++++++++++++++   docker-compose-rule  +++++++++++++++++
# +++++++++++++++++   android-priority-jobqueue  +++++++++++++++++
# +++++++++++++++++   material-calendarview  +++++++++++++++++
# +++++++++++++++++   react-native-track-player  +++++++++++++++++
# +++++++++++++++++   nanohttpd  +++++++++++++++++
# +++++++++++++++++   jpush-api-java-client  +++++++++++++++++
# Shape of passed values is (928, 45), indices imply (928, 66)
# +++++++++++++++++   coding2017  +++++++++++++++++
# Shape of passed values is (8930, 45), indices imply (8930, 66)
# +++++++++++++++++   bucket4j  +++++++++++++++++
# +++++++++++++++++   Sudachi  +++++++++++++++++
# +++++++++++++++++   requery  +++++++++++++++++
# +++++++++++++++++   volley  +++++++++++++++++
# +++++++++++++++++   java-apns  +++++++++++++++++
# +++++++++++++++++   osmtracker-android  +++++++++++++++++
# +++++++++++++++++   Android-Debug-Database  +++++++++++++++++
# Shape of passed values is (163, 45), indices imply (163, 66)
# +++++++++++++++++   retrolambda  +++++++++++++++++
# +++++++++++++++++   java  +++++++++++++++++
# Shape of passed values is (333, 45), indices imply (333, 66)
# +++++++++++++++++   TelegramBots  +++++++++++++++++
# +++++++++++++++++   liferay-docs  +++++++++++++++++
# +++++++++++++++++   bootique  +++++++++++++++++
# +++++++++++++++++   secor  +++++++++++++++++
# +++++++++++++++++   BottomSheetPickers  +++++++++++++++++
# +++++++++++++++++   android-advancedrecyclerview  +++++++++++++++++
# +++++++++++++++++   android-smsmms  +++++++++++++++++
# +++++++++++++++++   swiftp  +++++++++++++++++
# +++++++++++++++++   karyon  +++++++++++++++++
# +++++++++++++++++   jasmine-maven-plugin  +++++++++++++++++
# Shape of passed values is (1003, 45), indices imply (1003, 66)
# +++++++++++++++++   togglz  +++++++++++++++++
# +++++++++++++++++   GravityBox  +++++++++++++++++
# +++++++++++++++++   JASONETTE-Android  +++++++++++++++++
# +++++++++++++++++   ardublock  +++++++++++++++++
# +++++++++++++++++   oasp4j  +++++++++++++++++
# +++++++++++++++++   FreeFlow  +++++++++++++++++
# +++++++++++++++++   android_sdk  +++++++++++++++++
# Shape of passed values is (1039, 45), indices imply (1039, 66)
# +++++++++++++++++   mct  +++++++++++++++++
# +++++++++++++++++   MaterialDateTimePicker  +++++++++++++++++
# +++++++++++++++++   react-native-image-picker  +++++++++++++++++
# +++++++++++++++++   jfxtras  +++++++++++++++++
# +++++++++++++++++   spring-cloud-zookeeper  +++++++++++++++++
# +++++++++++++++++   yang  +++++++++++++++++
# Shape of passed values is (25, 45), indices imply (25, 66)
# +++++++++++++++++   clickhouse-jdbc  +++++++++++++++++
# Shape of passed values is (1265, 45), indices imply (1265, 66)
# +++++++++++++++++   jade4j  +++++++++++++++++
# +++++++++++++++++   griffin  +++++++++++++++++
# +++++++++++++++++   robospice  +++++++++++++++++
# +++++++++++++++++   TonY  +++++++++++++++++
# +++++++++++++++++   shimmer  +++++++++++++++++
# +++++++++++++++++   owner  +++++++++++++++++
# +++++++++++++++++   asynchbase  +++++++++++++++++
# +++++++++++++++++   abixen-platform  +++++++++++++++++
# +++++++++++++++++   simple-stack  +++++++++++++++++
# +++++++++++++++++   tilesfx  +++++++++++++++++
# +++++++++++++++++   Rosie  +++++++++++++++++
# +++++++++++++++++   andOTP  +++++++++++++++++
# +++++++++++++++++   gumtree  +++++++++++++++++
# +++++++++++++++++   hackerskeyboard  +++++++++++++++++
# Shape of passed values is (884, 45), indices imply (884, 66)
# +++++++++++++++++   GlobalPlatformPro  +++++++++++++++++
# +++++++++++++++++   flinkStreamSQL  +++++++++++++++++
# +++++++++++++++++   android_packages_apps_GmsCore  +++++++++++++++++
# +++++++++++++++++   forecastie  +++++++++++++++++
# +++++++++++++++++   StickyListHeaders  +++++++++++++++++
# +++++++++++++++++   spring-shell  +++++++++++++++++
# +++++++++++++++++   sardine  +++++++++++++++++
# +++++++++++++++++   consul-client  +++++++++++++++++
# Shape of passed values is (860, 45), indices imply (860, 66)
# +++++++++++++++++   NuProcess  +++++++++++++++++
# +++++++++++++++++   okbuck  +++++++++++++++++
# +++++++++++++++++   neuroph  +++++++++++++++++
# +++++++++++++++++   bitbucket-branch-source-plugin  +++++++++++++++++
# +++++++++++++++++   eclipse-collections  +++++++++++++++++
# +++++++++++++++++   RustDT  +++++++++++++++++
# +++++++++++++++++   google-http-java-client  +++++++++++++++++
# +++++++++++++++++   filemanager  +++++++++++++++++
# +++++++++++++++++   todo.txt-android  +++++++++++++++++
# +++++++++++++++++   firebase-android-sdk  +++++++++++++++++
# +++++++++++++++++   libsvm  +++++++++++++++++
# +++++++++++++++++   calendar-widget  +++++++++++++++++
# +++++++++++++++++   keywhiz  +++++++++++++++++
# +++++++++++++++++   Android-Image-Cropper  +++++++++++++++++
# +++++++++++++++++   fscrawler  +++++++++++++++++
# +++++++++++++++++   jfairy  +++++++++++++++++
# 'file_name'
# +++++++++++++++++   fdb-record-layer  +++++++++++++++++
# +++++++++++++++++   rxjava-jdbc  +++++++++++++++++
# +++++++++++++++++   aws-sdk-android  +++++++++++++++++
# +++++++++++++++++   webbit  +++++++++++++++++
# +++++++++++++++++   git-commit-id-maven-plugin  +++++++++++++++++
# +++++++++++++++++   openstack-java-sdk  +++++++++++++++++
# +++++++++++++++++   luwak  +++++++++++++++++
# +++++++++++++++++   sempre  +++++++++++++++++
# +++++++++++++++++   java-faker  +++++++++++++++++
# +++++++++++++++++   spring-integration-samples  +++++++++++++++++
# +++++++++++++++++   reddit-is-fun  +++++++++++++++++
# +++++++++++++++++   JavaHamcrest  +++++++++++++++++
# +++++++++++++++++   browser  +++++++++++++++++
# +++++++++++++++++   SimianArmy  +++++++++++++++++
# +++++++++++++++++   spring-boot-thin-launcher  +++++++++++++++++
# +++++++++++++++++   Mallet  +++++++++++++++++
# +++++++++++++++++   jongo  +++++++++++++++++
# +++++++++++++++++   dsl-json  +++++++++++++++++
# +++++++++++++++++   seldon-server  +++++++++++++++++
# +++++++++++++++++   azure-spring-boot  +++++++++++++++++
# +++++++++++++++++   wasabi  +++++++++++++++++
# +++++++++++++++++   mosby  +++++++++++++++++
# +++++++++++++++++   twoway-view  +++++++++++++++++
# +++++++++++++++++   gitiles  +++++++++++++++++
# +++++++++++++++++   extentreports-java  +++++++++++++++++
# +++++++++++++++++   arquillian-core  +++++++++++++++++
# +++++++++++++++++   manifold  +++++++++++++++++
# +++++++++++++++++   epoxy  +++++++++++++++++
# +++++++++++++++++   Elephant  +++++++++++++++++
# +++++++++++++++++   webcam-capture  +++++++++++++++++
# +++++++++++++++++   angel  +++++++++++++++++
# +++++++++++++++++   litemall  +++++++++++++++++
# +++++++++++++++++   junit-plugin  +++++++++++++++++
# +++++++++++++++++   Lightweight-Stream-API  +++++++++++++++++
# +++++++++++++++++   phonegap-plugins  +++++++++++++++++
# +++++++++++++++++   apicurio-studio  +++++++++++++++++
# +++++++++++++++++   light-task-scheduler  +++++++++++++++++
# +++++++++++++++++   RxJava-Android-Samples  +++++++++++++++++
# +++++++++++++++++   super-csv  +++++++++++++++++
# +++++++++++++++++   java-sdk  +++++++++++++++++
# +++++++++++++++++   cassandra-unit  +++++++++++++++++
# +++++++++++++++++   copycat  +++++++++++++++++
# +++++++++++++++++   google-api-java-client  +++++++++++++++++
# +++++++++++++++++   android-pulltorefresh  +++++++++++++++++
# +++++++++++++++++   bdd-security  +++++++++++++++++
# +++++++++++++++++   google-java-format  +++++++++++++++++
# +++++++++++++++++   fixflow  +++++++++++++++++
# +++++++++++++++++   java-gitlab-api  +++++++++++++++++
# +++++++++++++++++   andlytics  +++++++++++++++++
# +++++++++++++++++   jdeb  +++++++++++++++++
# +++++++++++++++++   samza  +++++++++++++++++
# +++++++++++++++++   spring-security-saml  +++++++++++++++++
# +++++++++++++++++   spring-restdocs  +++++++++++++++++
# +++++++++++++++++   OpenIAB  +++++++++++++++++
# +++++++++++++++++   product-ei  +++++++++++++++++
# Shape of passed values is (7194, 45), indices imply (7194, 66)
# +++++++++++++++++   nginx-clojure  +++++++++++++++++
# +++++++++++++++++   react-native-mapbox-gl  +++++++++++++++++
# +++++++++++++++++   governator  +++++++++++++++++
# +++++++++++++++++   android-beacon-library  +++++++++++++++++
# +++++++++++++++++   spring-cloud-consul  +++++++++++++++++
# +++++++++++++++++   beetl2.0  +++++++++++++++++
# +++++++++++++++++   restlet-framework-java  +++++++++++++++++
# Shape of passed values is (4096, 45), indices imply (4096, 66)
# +++++++++++++++++   addressbook-level4  +++++++++++++++++
# +++++++++++++++++   sqlite-jdbc  +++++++++++++++++
# +++++++++++++++++   Travel-Mate  +++++++++++++++++
# +++++++++++++++++   HotswapAgent  +++++++++++++++++
# +++++++++++++++++   kafka-connect-jdbc  +++++++++++++++++
# +++++++++++++++++   pippo  +++++++++++++++++
# +++++++++++++++++   SeLion  +++++++++++++++++
# +++++++++++++++++   600SeriesAndroidUploader  +++++++++++++++++
# +++++++++++++++++   addressbook-level3  +++++++++++++++++
# +++++++++++++++++   openmrs-contrib-android-client  +++++++++++++++++
# Shape of passed values is (3024, 45), indices imply (3024, 66)
# +++++++++++++++++   jcommander  +++++++++++++++++
# +++++++++++++++++   athenz  +++++++++++++++++
# +++++++++++++++++   materialistic  +++++++++++++++++
# +++++++++++++++++   TweetLanes  +++++++++++++++++
# +++++++++++++++++   s3proxy  +++++++++++++++++
# +++++++++++++++++   metacat  +++++++++++++++++
# +++++++++++++++++   J2ME-Loader  +++++++++++++++++
# +++++++++++++++++   react-native-iap  +++++++++++++++++
# +++++++++++++++++   leshan  +++++++++++++++++
# +++++++++++++++++   cucumber-reporting  +++++++++++++++++
# +++++++++++++++++   unfolding  +++++++++++++++++
# +++++++++++++++++   redis-manager  +++++++++++++++++
# +++++++++++++++++   java-driver  +++++++++++++++++
# +++++++++++++++++   tx-lcn  +++++++++++++++++
# +++++++++++++++++   SecurityShepherd  +++++++++++++++++
# Shape of passed values is (1918, 45), indices imply (1918, 66)
# +++++++++++++++++   subclipse  +++++++++++++++++
# +++++++++++++++++   couchdb-lucene  +++++++++++++++++
# +++++++++++++++++   programming  +++++++++++++++++
# Shape of passed values is (211, 45), indices imply (211, 66)
# +++++++++++++++++   OpenRTS  +++++++++++++++++
# Shape of passed values is (3997, 45), indices imply (3997, 66)
# +++++++++++++++++   spectator  +++++++++++++++++
# Shape of passed values is (1895, 45), indices imply (1895, 66)
# +++++++++++++++++   storio  +++++++++++++++++
# Shape of passed values is (3700, 45), indices imply (3700, 66)
# +++++++++++++++++   Solandra  +++++++++++++++++
# +++++++++++++++++   keepassdroid  +++++++++++++++++
# +++++++++++++++++   opennlp  +++++++++++++++++
# +++++++++++++++++   jboss-eap-quickstarts  +++++++++++++++++
# +++++++++++++++++   java-client-api  +++++++++++++++++
# +++++++++++++++++   swagger2markup  +++++++++++++++++
# +++++++++++++++++   logisim-evolution  +++++++++++++++++
# Shape of passed values is (6808, 45), indices imply (6808, 66)
# +++++++++++++++++   picasso  +++++++++++++++++
# +++++++++++++++++   moa  +++++++++++++++++
# +++++++++++++++++   physical-web  +++++++++++++++++
# +++++++++++++++++   Minim  +++++++++++++++++
# +++++++++++++++++   photon  +++++++++++++++++
# +++++++++++++++++   failsafe  +++++++++++++++++
# +++++++++++++++++   JAdventure  +++++++++++++++++
# +++++++++++++++++   htm.java  +++++++++++++++++
# +++++++++++++++++   FreeBuilder  +++++++++++++++++
# +++++++++++++++++   ExoMedia  +++++++++++++++++
# +++++++++++++++++   disunity  +++++++++++++++++
# +++++++++++++++++   docker-plugin  +++++++++++++++++
# +++++++++++++++++   Medusa  +++++++++++++++++
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   micro-server  +++++++++++++++++
# +++++++++++++++++   swagger-maven-plugin  +++++++++++++++++
# +++++++++++++++++   PretendYoureXyzzy  +++++++++++++++++
# +++++++++++++++++   BaseRecyclerViewAdapterHelper  +++++++++++++++++
# +++++++++++++++++   sshj  +++++++++++++++++
# +++++++++++++++++   bither-android  +++++++++++++++++
# +++++++++++++++++   Telegram  +++++++++++++++++
# +++++++++++++++++   graphicsfuzz  +++++++++++++++++
# +++++++++++++++++   Telegram-FOSS  +++++++++++++++++
# +++++++++++++++++   RxAndroidBle  +++++++++++++++++
# +++++++++++++++++   spring-ldap  +++++++++++++++++
# +++++++++++++++++   gpstest  +++++++++++++++++
# +++++++++++++++++   BitcoinChecker  +++++++++++++++++
# +++++++++++++++++   memcached-session-manager  +++++++++++++++++
# +++++++++++++++++   JsonPath  +++++++++++++++++
# +++++++++++++++++   RichTextFX  +++++++++++++++++
# +++++++++++++++++   raml-for-jax-rs  +++++++++++++++++
# +++++++++++++++++   light-admin  +++++++++++++++++
# +++++++++++++++++   jetcache  +++++++++++++++++
# +++++++++++++++++   crash  +++++++++++++++++
# +++++++++++++++++   Grammar-Kit  +++++++++++++++++
# +++++++++++++++++   macrobase  +++++++++++++++++
# +++++++++++++++++   hera  +++++++++++++++++
# +++++++++++++++++   influxdb-java  +++++++++++++++++
# +++++++++++++++++   subversion-plugin  +++++++++++++++++
# +++++++++++++++++   UltimateRecyclerView  +++++++++++++++++
# +++++++++++++++++   spikes  +++++++++++++++++
# Shape of passed values is (1621, 45), indices imply (1621, 66)
# +++++++++++++++++   ff4j  +++++++++++++++++
# +++++++++++++++++   zotfile  +++++++++++++++++
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   ion  +++++++++++++++++
# +++++++++++++++++   ChromeLikeTabSwitcher  +++++++++++++++++
# +++++++++++++++++   openstack4j  +++++++++++++++++
# +++++++++++++++++   artifactory-plugin  +++++++++++++++++
# +++++++++++++++++   openmrs-module-webservices.rest  +++++++++++++++++
# +++++++++++++++++   java-memcached-client  +++++++++++++++++
# +++++++++++++++++   parboiled  +++++++++++++++++
# Shape of passed values is (4015, 45), indices imply (4015, 66)
# +++++++++++++++++   open-event-organizer-android  +++++++++++++++++
# +++++++++++++++++   jline2  +++++++++++++++++
# +++++++++++++++++   gwt-bootstrap  +++++++++++++++++
# +++++++++++++++++   waffle  +++++++++++++++++
# +++++++++++++++++   springside4  +++++++++++++++++
# +++++++++++++++++   disruptor  +++++++++++++++++
# +++++++++++++++++   android-async-http  +++++++++++++++++
# +++++++++++++++++   logbook  +++++++++++++++++
# +++++++++++++++++   ActionBarSherlock  +++++++++++++++++
# +++++++++++++++++   config  +++++++++++++++++
# +++++++++++++++++   getdown  +++++++++++++++++
# +++++++++++++++++   jzmq  +++++++++++++++++
# +++++++++++++++++   roboguice  +++++++++++++++++
# Shape of passed values is (3432, 45), indices imply (3432, 66)
# +++++++++++++++++   hollow  +++++++++++++++++
# +++++++++++++++++   fest-assert-2.x  +++++++++++++++++
# +++++++++++++++++   spring-social-facebook  +++++++++++++++++
# +++++++++++++++++   jediterm  +++++++++++++++++
# +++++++++++++++++   netty-socketio  +++++++++++++++++
# Shape of passed values is (1213, 45), indices imply (1213, 66)
# +++++++++++++++++   Easer  +++++++++++++++++
# +++++++++++++++++   pi4j  +++++++++++++++++
# Shape of passed values is (1811, 45), indices imply (1811, 66)
# +++++++++++++++++   lcm  +++++++++++++++++
# +++++++++++++++++   jmeter-maven-plugin  +++++++++++++++++
# +++++++++++++++++   find-sec-bugs  +++++++++++++++++
# Shape of passed values is (3287, 45), indices imply (3287, 66)
# +++++++++++++++++   mongo-hadoop  +++++++++++++++++
# Shape of passed values is (1321, 45), indices imply (1321, 66)
# +++++++++++++++++   jackson-dataformat-xml  +++++++++++++++++
# +++++++++++++++++   ice-demos  +++++++++++++++++
# +++++++++++++++++   librec  +++++++++++++++++
# +++++++++++++++++   spring-cloud-function  +++++++++++++++++
# +++++++++++++++++   multi-model-server  +++++++++++++++++
# +++++++++++++++++   Android-Orma  +++++++++++++++++
# +++++++++++++++++   mapbox-android-demo  +++++++++++++++++
# +++++++++++++++++   cruise-control  +++++++++++++++++
# +++++++++++++++++   allure2  +++++++++++++++++
# +++++++++++++++++   mamute  +++++++++++++++++
# +++++++++++++++++   Hystrix  +++++++++++++++++
# +++++++++++++++++   giraph  +++++++++++++++++
# +++++++++++++++++   remote-desktop-clients  +++++++++++++++++
# +++++++++++++++++   astyanax  +++++++++++++++++
# +++++++++++++++++   javacpp  +++++++++++++++++
# Shape of passed values is (1221, 45), indices imply (1221, 66)
# +++++++++++++++++   XChart  +++++++++++++++++
# +++++++++++++++++   cucumber  +++++++++++++++++
# +++++++++++++++++   maps  +++++++++++++++++
# +++++++++++++++++   stripe-java  +++++++++++++++++
# +++++++++++++++++   HoloEverywhere  +++++++++++++++++
# Shape of passed values is (4105, 45), indices imply (4105, 66)
# +++++++++++++++++   RSyntaxTextArea  +++++++++++++++++
# +++++++++++++++++   facebook-android-sdk  +++++++++++++++++
# +++++++++++++++++   malmo  +++++++++++++++++
# +++++++++++++++++   GCViewer  +++++++++++++++++
# +++++++++++++++++   lucida  +++++++++++++++++
# Shape of passed values is (1064, 45), indices imply (1064, 66)
# +++++++++++++++++   handlebars.java  +++++++++++++++++
# +++++++++++++++++   stringtemplate4  +++++++++++++++++
# +++++++++++++++++   RxNetty  +++++++++++++++++
# Shape of passed values is (4407, 45), indices imply (4407, 66)
# +++++++++++++++++   ghprb-plugin  +++++++++++++++++
# +++++++++++++++++   xmemcached  +++++++++++++++++
# Shape of passed values is (3018, 45), indices imply (3018, 66)
# +++++++++++++++++   guacamole-client  +++++++++++++++++
# Shape of passed values is (1622, 45), indices imply (1622, 66)
# +++++++++++++++++   KernelAdiutor  +++++++++++++++++
# +++++++++++++++++   chat-sdk-android  +++++++++++++++++
# +++++++++++++++++   Duke  +++++++++++++++++
# +++++++++++++++++   EhViewer  +++++++++++++++++
# +++++++++++++++++   goclipse  +++++++++++++++++
# +++++++++++++++++   Jest  +++++++++++++++++
# +++++++++++++++++   flume  +++++++++++++++++
# +++++++++++++++++   android-testdpc  +++++++++++++++++
# +++++++++++++++++   samourai-wallet-android  +++++++++++++++++
# +++++++++++++++++   jbehave-core  +++++++++++++++++
# +++++++++++++++++   pushy  +++++++++++++++++
# +++++++++++++++++   boon  +++++++++++++++++
# +++++++++++++++++   spring-data-solr  +++++++++++++++++
# +++++++++++++++++   javassist  +++++++++++++++++
# +++++++++++++++++   uhabits  +++++++++++++++++
# Shape of passed values is (3961, 45), indices imply (3961, 66)
# +++++++++++++++++   spock  +++++++++++++++++
# +++++++++++++++++   PageTurner  +++++++++++++++++
# +++++++++++++++++   heroic  +++++++++++++++++
# +++++++++++++++++   univocity-parsers  +++++++++++++++++
# +++++++++++++++++   twilio-java  +++++++++++++++++
# +++++++++++++++++   TrebleShot  +++++++++++++++++
# +++++++++++++++++   interview  +++++++++++++++++
# +++++++++++++++++   jsprit  +++++++++++++++++
# +++++++++++++++++   focus-android  +++++++++++++++++
# +++++++++++++++++   spring-cloud-commons  +++++++++++++++++
# +++++++++++++++++   spring-hateoas  +++++++++++++++++
# +++++++++++++++++   flinkx  +++++++++++++++++
# +++++++++++++++++   streamex  +++++++++++++++++
# +++++++++++++++++   testcontainers-java  +++++++++++++++++
# +++++++++++++++++   connectbot  +++++++++++++++++
# +++++++++++++++++   json-schema  +++++++++++++++++
# +++++++++++++++++   msf4j  +++++++++++++++++
# +++++++++++++++++   spring-kafka  +++++++++++++++++
# Shape of passed values is (2731, 45), indices imply (2731, 66)
# +++++++++++++++++   HiBench  +++++++++++++++++
# Shape of passed values is (3939, 45), indices imply (3939, 66)
# +++++++++++++++++   embulk  +++++++++++++++++
# +++++++++++++++++   jbake  +++++++++++++++++
# +++++++++++++++++   gravitee-gateway  +++++++++++++++++
# +++++++++++++++++   jcodec  +++++++++++++++++
# +++++++++++++++++   spring-social  +++++++++++++++++
# +++++++++++++++++   pebble  +++++++++++++++++
# +++++++++++++++++   CameraView  +++++++++++++++++
# +++++++++++++++++   py4j  +++++++++++++++++
# +++++++++++++++++   schema-registry  +++++++++++++++++
# +++++++++++++++++   jedis  +++++++++++++++++
# +++++++++++++++++   download-manager  +++++++++++++++++
# +++++++++++++++++   AppiumTestDistribution  +++++++++++++++++
# +++++++++++++++++   incubator-hudi  +++++++++++++++++
# +++++++++++++++++   XposedInstaller  +++++++++++++++++
# Shape of passed values is (1491, 45), indices imply (1491, 66)
# +++++++++++++++++   jBrowserDriver  +++++++++++++++++
# +++++++++++++++++   spring-cloud-aws  +++++++++++++++++
# +++++++++++++++++   rtmp-rtsp-stream-client-java  +++++++++++++++++
# Shape of passed values is (2531, 45), indices imply (2531, 66)
# +++++++++++++++++   spring-data-rest  +++++++++++++++++
# +++++++++++++++++   PokeGOAPI-Java  +++++++++++++++++
# +++++++++++++++++   github-api  +++++++++++++++++
# +++++++++++++++++   Book-Catalogue  +++++++++++++++++
# +++++++++++++++++   RedReader  +++++++++++++++++
# +++++++++++++++++   BiglyBT  +++++++++++++++++
# +++++++++++++++++   parquet-mr  +++++++++++++++++
# +++++++++++++++++   jsoup  +++++++++++++++++
# +++++++++++++++++   cassandra-lucene-index  +++++++++++++++++
# +++++++++++++++++   AndroidAsync  +++++++++++++++++
# +++++++++++++++++   cyclops-integration  +++++++++++++++++
# +++++++++++++++++   opsu  +++++++++++++++++
# Shape of passed values is (2375, 45), indices imply (2375, 66)
# +++++++++++++++++   metrics  +++++++++++++++++
# +++++++++++++++++   amidst  +++++++++++++++++
# +++++++++++++++++   jsweet  +++++++++++++++++
# +++++++++++++++++   pgjdbc-ng  +++++++++++++++++
# +++++++++++++++++   qbit  +++++++++++++++++
# Shape of passed values is (5962, 45), indices imply (5962, 66)
# +++++++++++++++++   thingsboard  +++++++++++++++++
# +++++++++++++++++   blueflood  +++++++++++++++++
# +++++++++++++++++   androidannotations  +++++++++++++++++
# +++++++++++++++++   digdag  +++++++++++++++++
# +++++++++++++++++   openrouteservice  +++++++++++++++++
# +++++++++++++++++   nzbhydra2  +++++++++++++++++
# +++++++++++++++++   phpinspectionsea  +++++++++++++++++
# +++++++++++++++++   phoenicis  +++++++++++++++++
# Shape of passed values is (272, 45), indices imply (272, 66)
# +++++++++++++++++   guice  +++++++++++++++++
# +++++++++++++++++   chunky  +++++++++++++++++
# +++++++++++++++++   dropwizard  +++++++++++++++++
# +++++++++++++++++   Digital  +++++++++++++++++
# +++++++++++++++++   intellij-elixir  +++++++++++++++++
# +++++++++++++++++   nakadi  +++++++++++++++++
# +++++++++++++++++   Discord4J  +++++++++++++++++
# +++++++++++++++++   OpenRefine  +++++++++++++++++
# +++++++++++++++++   nokogiri  +++++++++++++++++
# +++++++++++++++++   rapidoid  +++++++++++++++++
# +++++++++++++++++   druid  +++++++++++++++++

# %%
with open('results/Performance/commit_guru_file_specific/process+product_700_svc_5_fold_5_repeat.pkl', 'wb') as handle:
    pickle.dump(final_result, handle, protocol=pickle.HIGHEST_PROTOCOL)

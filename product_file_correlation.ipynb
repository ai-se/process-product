# %%
import pandas as pd
import numpy as np
import math
import pickle

from scipy import stats
import scipy.io
from scipy.spatial.distance import pdist
from scipy.linalg import cholesky
from scipy.io import loadmat

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report,roc_auc_score,recall_score,precision_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA

from src import SMOTE
from src import CFS
from src import metrices_V2 as metrices

import platform
from os import listdir
from os.path import isfile, join
from glob import glob
from pathlib import Path
import sys
import os
import copy
import traceback
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Load and other util function

# %%
def load_data(project):
    understand_path = 'data/understand_files_all/' + project + '_understand.csv'
    understand_df = pd.read_csv(understand_path)
    understand_df = understand_df.dropna(axis = 1,how='all')
    cols_list = understand_df.columns.values.tolist()
#     print(cols_list)
    for item in ['Kind','commit_hash', 'Bugs']:
        if item in cols_list:
            cols_list.remove(item)
            cols_list.insert(0,item)
    understand_df = understand_df[cols_list]
    cols = understand_df.columns.tolist()

    understand_df = understand_df.drop_duplicates(cols[4:len(cols)])
    df = understand_df
    for item in ['Kind','commit_hash']:
        if item in cols:
            df = df.drop(labels = [item],axis=1)
    df.dropna(inplace=True)
    print(df.shape)
    return df

def apply_smote(df):
    cols = df.columns
    smt = SMOTE.smote(df)
    df = smt.run()
    df.columns = cols
    return df

def apply_cfs(df):
        y = df.Bugs.values
        X = df.drop(labels = ['Bugs'],axis = 1)
        X = X.values
        selected_cols = CFS.cfs(X,y)
        cols = df.columns[[selected_cols]].tolist()
        cols.append('Bugs')
        return df[cols],cols

def get_spearmanr(df):
    df = df.drop('Bugs',axis = 1)
    file_corr = []
    for name in df.Name.unique():
        sub_df = df[df['Name'] == name]
        if sub_df.shape[0] < 2:
            continue
        sub_df = sub_df.drop('Name',axis = 1)
        rho, pval = stats.spearmanr(sub_df.values,sub_df.values,axis = 1)
        file_corr.append(np.median(rho[:,:int(len(rho)/2)]))
    return file_corr

# %% [markdown]
# # Getting List of projects

# %%
proj_df = pd.read_csv('projects.csv')
projects = proj_df.repo_name.tolist()

# %% [markdown]
# # Run the experiment

# %%
project_corr = {}
for project in projects[0:100]:
    try:
        if project == '.DS_Store':
            continue
#         if project != 'Pokemap':
#             continue
        print("+++++++++++++++++   "  + project + "  +++++++++++++++++")
        df = load_data(project)
        _corr = []
        for file in df.Name.unique():
            sub_df = df[df['Name'] == file]
            if sub_df.shape[0] == 1:
                continue
            print((sub_df.columns))
            sub_df.drop(labels = ['Name'],axis = 1,inplace = True)
            corr = get_spearmanr(sub_df)
            _corr.append(corr)
            print(np.median(corr))
        project_corr[project] = corr
    except Exception as e:
        print(e)
        continue
# with open('results/Performance/product_corr.pkl', 'wb') as handle:
#     pickle.dump(project_corr, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# +++++++++++++++++   org.alloytools.alloy  +++++++++++++++++
# (764, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   qpython  +++++++++++++++++
# (409, 47)
# +++++++++++++++++   friendlychat-android  +++++++++++++++++
# (24, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   paho.mqtt.android  +++++++++++++++++
# (78, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   paho.mqtt.java  +++++++++++++++++
# (276, 47)
# +++++++++++++++++   android-docs-samples  +++++++++++++++++
# (50, 47)
# +++++++++++++++++   Toasty  +++++++++++++++++
# (10, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   android-mvvm-architecture  +++++++++++++++++
# (18, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   recipes-rss  +++++++++++++++++
# (34, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   HoloGraphLibrary  +++++++++++++++++
# (30, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   HorizontalWheelView  +++++++++++++++++
# (10, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   OpenMemories-Tweak  +++++++++++++++++
# (55, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   HoldingButton  +++++++++++++++++
# (23, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   ExpandableLayout  +++++++++++++++++
# (22, 47)
# +++++++++++++++++   RecyclerView-MultipleViewTypesAdapter  +++++++++++++++++
# (17, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   UpdateApp  +++++++++++++++++
# (8, 47)
# +++++++++++++++++   activate-power-mode  +++++++++++++++++
# (34, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   JDAddressSelector  +++++++++++++++++
# (19, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   android-ago  +++++++++++++++++
# (19, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   cordova-plugin-streaming-media  +++++++++++++++++
# (8, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   birt  +++++++++++++++++
# (11584, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   arquillian-examples  +++++++++++++++++
# (64, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   dex-method-counts  +++++++++++++++++
# (28, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   google-authenticator-android  +++++++++++++++++
# (274, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   android-samples  +++++++++++++++++
# (88, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   PLDroidMediaStreaming  +++++++++++++++++
# (79, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   hacktoberfest-2019  +++++++++++++++++
# (18, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   egit-github  +++++++++++++++++
# (390, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   Hello-World  +++++++++++++++++
# (2, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   API-NG-sample-code  +++++++++++++++++
# (91, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   openshift-quickstarts  +++++++++++++++++
# (28, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   http-request  +++++++++++++++++
# (53, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   NumberProgressBar  +++++++++++++++++
# (9, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   eclipse.jdt.ls  +++++++++++++++++
# (1389, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   portfolio  +++++++++++++++++
# (1639, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   DataSphereStudio  +++++++++++++++++
# (254, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   mapstruct-examples  +++++++++++++++++
# (78, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   amazon-kinesis-connectors  +++++++++++++++++
# (82, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   Android-ExpandIcon  +++++++++++++++++
# (7, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   MyLittleCanvas  +++++++++++++++++
# (75, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   Dachshund-Tab-Layout  +++++++++++++++++
# (15, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   Pix-EzViewer  +++++++++++++++++
# (84, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   FastScroll  +++++++++++++++++
# (15, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   recyclerviewhelper  +++++++++++++++++
# (18, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   MaterialFavoriteButton  +++++++++++++++++
# (15, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   MaterialPreferenceLibrary  +++++++++++++++++
# (38, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   CircleSeekbar  +++++++++++++++++
# (17, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   TaskScheduler  +++++++++++++++++
# (33, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   TextLayoutBuilder  +++++++++++++++++
# (53, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   BubbleView  +++++++++++++++++
# (15, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   Mappedbus  +++++++++++++++++
# (44, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   project-rome  +++++++++++++++++
# (123, 47)
# Index(['Bugs', 'Name', 'AvgCyclomatic', 'AvgCyclomaticModified',
#        'AvgCyclomaticStrict', 'AvgEssential', 'AvgLine', 'AvgLineBlank',
#        'AvgLineCode', 'AvgLineComment', 'CountClassBase', 'CountClassCoupled',
#        'CountClassCoupledModified', 'CountClassDerived',
#        'CountDeclClassMethod', 'CountDeclClassVariable',
#        'CountDeclInstanceMethod', 'CountDeclInstanceVariable',
#        'CountDeclMethod', 'CountDeclMethodAll', 'CountDeclMethodDefault',
#        'CountDeclMethodPrivate', 'CountDeclMethodProtected',
#        'CountDeclMethodPublic', 'CountLine', 'CountLineBlank', 'CountLineCode',
#        'CountLineCodeDecl', 'CountLineCodeExe', 'CountLineComment',
#        'CountSemicolon', 'CountStmt', 'CountStmtDecl', 'CountStmtExe',
#        'MaxCyclomatic', 'MaxCyclomaticModified', 'MaxCyclomaticStrict',
#        'MaxEssential', 'MaxInheritanceTree', 'MaxNesting',
#        'PercentLackOfCohesion', 'PercentLackOfCohesionModified',
#        'RatioCommentToCode', 'SumCyclomatic', 'SumCyclomaticModified',
#        'SumCyclomaticStrict', 'SumEssential'],
#       dtype='object')
# 'DataFrame' object has no attribute 'Name'
# +++++++++++++++++   sbt-android  +++++++++++++++++
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-fb44bcfc613d> in <module>
#       7 #             continue
#       8         print("+++++++++++++++++   "  + project + "  +++++++++++++++++")
# ----> 9         df = load_data(project)
#      10         _corr = []
#      11         for file in df.Name.unique():
#
# <ipython-input-37-11bf17fb383d> in load_data(project)
#      12     cols = understand_df.columns.tolist()
#      13
# ---> 14     understand_df = understand_df.drop_duplicates(cols[4:len(cols)])
#      15     df = understand_df
#      16     for item in ['Kind','commit_hash']:
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    4628
#    4629         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 4630         duplicated = self.duplicated(subset, keep=keep)
#    4631
#    4632         if inplace:
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4685         vals = (col.values for name, col in self.iteritems()
#    4686                 if name in subset)
# -> 4687         labels, shape = map(list, zip(*map(f, vals)))
#    4688
#    4689         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in f(vals)
#    4666         def f(vals):
#    4667             labels, shape = algorithms.factorize(
# -> 4668                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT))
#    4669             return labels.astype('i8', copy=False), len(shape)
#    4670
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     611                                            na_sentinel=na_sentinel,
#     612                                            size_hint=size_hint,
# --> 613                                            na_value=na_value)
#     614
#     615     if sort and len(uniques) > 0:
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     458     table = hash_klass(size_hint or len(values))
#     459     uniques, labels = table.factorize(values, na_sentinel=na_sentinel,
# --> 460                                       na_value=na_value)
#     461
#     462     labels = ensure_platform_int(labels)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable._unique()
#
# ~/Conda/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     467
#     468
# --> 469 @set_module('numpy')
#     470 def asarray(a, dtype=None, order=None):
#     471     """Convert the input to an array.
#
# KeyboardInterrupt:

# %%
# project_corr = pd.read_pickle('results/Performance/product_corr.pkl')
flat_list = [item for sublist in list(project_corr.values()) for item in sublist]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
bp = ax.violinplot(flat_list,showmedians=True,points=50,bw_method='scott')

# %%
# project_corr = pd.read_pickle('results/Performance/product_corr.pkl')
flat_list = [item for sublist in list(project_corr.values()) for item in sublist]
ax = sns.violinplot(y=flat_list)

# %%
df
# Out:
#     Bugs                                               Name  AvgCyclomatic  \
# 0      1             info.abdolahi.CircularMusicProgressBar            1.0
# 1      0  info.abdolahi.CircularMusicProgressBar.init.(A...            1.0
# 2      0  info.abdolahi.circularmusicbarsample.MainActivity            1.0
# 3      0             info.abdolahi.CircularMusicProgressBar            1.0
# 6      1             info.abdolahi.CircularMusicProgressBar            1.0
# 7      1  info.abdolahi.circularmusicbarsample.MainActivity            1.0
# 8      0  info.abdolahi.CircularMusicProgressBar.init.(A...            1.0
# 9      0  info.abdolahi.CircularMusicProgressBar.setupGe...            1.0
# 10     0  info.abdolahi.circularmusicbarsample.MainActiv...            1.0
# 14     0  info.abdolahi.circularmusicbarsample.MainActivity            1.0
# 15     1             info.abdolahi.CircularMusicProgressBar            1.0
#
#     AvgCyclomaticModified  AvgCyclomaticStrict  AvgEssential  AvgLine  \
# 0                     1.0                  1.0           1.0      9.0
# 1                     1.0                  1.0           1.0      4.0
# 2                     1.0                  1.0           1.0     11.0
# 3                     1.0                  1.0           1.0      9.0
# 6                     1.0                  1.0           1.0     10.0
# 7                     1.0                  1.0           1.0     21.0
# 8                     1.0                  1.0           1.0      3.0
# 9                     1.0                  1.0           1.0      5.0
# 10                    1.0                  1.0           1.0      3.0
# 14                    1.0                  1.0           1.0      7.0
# 15                    1.0                  1.0           1.0     10.0
#
#     AvgLineBlank  AvgLineCode  AvgLineComment  ...  MaxEssential  \
# 0            1.0          7.0             0.0  ...           4.0
# 1            0.0          4.0             0.0  ...           1.0
# 2            4.0          6.0             1.0  ...           1.0
# 3            1.0          7.0             0.0  ...           4.0
# 6            1.0          8.0             0.0  ...           4.0
# 7            4.0         16.0             1.0  ...           1.0
# 8            0.0          3.0             0.0  ...           1.0
# 9            0.0          5.0             0.0  ...           3.0
# 10           0.0          3.0             0.0  ...           1.0
# 14           1.0          5.0             0.0  ...           1.0
# 15           1.0          8.0             0.0  ...           4.0
#
#     MaxInheritanceTree  MaxNesting  PercentLackOfCohesion  \
# 0                  2.0           2                   93.0
# 1                  2.0           0                    0.0
# 2                  2.0           0                    0.0
# 3                  2.0           2                   93.0
# 6                  2.0           2                   93.0
# 7                  2.0           0                    0.0
# 8                  2.0           0                    0.0
# 9                  2.0           2                    0.0
# 10                 1.0           0                    0.0
# 14                 2.0           0                    0.0
# 15                 2.0           2                   94.0
#
#     PercentLackOfCohesionModified  RatioCommentToCode  SumCyclomatic  \
# 0                            64.0                0.10             68
# 1                             0.0                0.00              1
# 2                             0.0                0.10              1
# 3                            63.0                0.10             67
# 6                            71.0                0.10             80
# 7                             0.0                0.08              2
# 8                             0.0                0.00              1
# 9                             0.0                0.00             10
# 10                            0.0                0.00              3
# 14                            0.0                0.07              2
# 15                           72.0                0.09             85
#
#     SumCyclomaticModified  SumCyclomaticStrict  SumEssential
# 0                      68                   70            47
# 1                       1                    1             1
# 2                       1                    1             1
# 3                      67                   69            47
# 6                      80                   83            55
# 7                       2                    2             2
# 8                       1                    1             1
# 9                      10                   10             8
# 10                      3                    3             3
# 14                      2                    2             2
# 15                     83                   88            57
#
# [11 rows x 47 columns]
